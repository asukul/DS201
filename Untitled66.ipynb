# %% [markdown]
# <a href="https://colab.research.google.com/github/asukul/DS201/blob/master/Untitled66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/asukul/DS201/master/datasets/Automobile_price_data_clean2.csv"
df = pd.read_csv(url)
display(df.head())
# Out:
#          make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 0   chevrolet       gas        std          two  hatchback          fwd
# 1  volkswagen    diesel        std          two      sedan          fwd
# 2  volkswagen    diesel        std         four      sedan          fwd
# 3      nissan    diesel        std          two      sedan          fwd
# 4      toyota    diesel        std         four  hatchback          fwd
#
#   engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0           front        88.4   141.1   60.3  ...           61         2bbl
# 1           front        97.3   171.7   65.5  ...           97          idi
# 2           front        97.3   171.7   65.5  ...           97          idi
# 3           front        94.5   165.3   63.8  ...          103          idi
# 4           front        95.7   166.3   64.4  ...          110          idi
#
# ...
